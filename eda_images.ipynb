# %%
image_root = "../data/images"

print("Image root folders:")
print(os.listdir(image_root))

image_base_path = "../data/images/bottle"

print("Bottle dataset folders:")
print(os.listdir(image_base_path))

train_path = os.path.join(image_base_path, "train")

print("Train classes:")
print(os.listdir(train_path))

from PIL import Image
import matplotlib.pyplot as plt

class_name = os.listdir(train_path)[0]
class_path = os.path.join(train_path, class_name)

img_name = os.listdir(class_path)[0]
img_path = os.path.join(class_path, img_name)

img = Image.open(img_path)

plt.imshow(img)
plt.axis("off")
plt.title(f"Class: {class_name}")
plt.show()
