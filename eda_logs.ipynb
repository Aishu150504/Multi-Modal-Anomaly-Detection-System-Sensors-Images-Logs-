# %%
import os

log_root = "../data/logs"

print(os.listdir(log_root))

# %%
log_base_path = "../data/logs/logs/ADFA-LD"

print("ADFA-LD contents:")
print(os.listdir(log_base_path))

# %%
attack_path = os.path.join(log_base_path, "Attack_Data_Master")

files = os.listdir(attack_path)

print("Number of attack files:", len(files))
print("Sample file:", files[0])

# %%
with open(os.path.join(attack_path, files[0]), "r") as f:
    print(f.read()[:300])

# %%
import os

log_root = "../data/logs"

print(os.listdir(log_root))
log_base_path = "../data/logs/logs/ADFA-LD"

print("ADFA-LD contents:")
print(os.listdir(log_base_path))
attack_path = os.path.join(log_base_path, "Attack_Data_Master")

files = os.listdir(attack_path)

print("Number of attack files:", len(files))
print("Sample file:", files[0])
with open(os.path.join(attack_path, files[0]), "r") as f:
    print(f.read()[:300])
