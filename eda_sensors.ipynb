# %%
import pandas as pd
import matplotlib.pyplot as plt

# CORRECT PATH (from eda/)
sensor_path = "../data/sensors/train_FD001.txt"

df = pd.read_csv(
    sensor_path,
    sep=r"\s+",      # IMPORTANT for NASA data
    header=None
)

df = df.dropna(axis=1)

print("✅ Sensor data loaded")
print("Shape:", df.shape)

import pandas as pd
import matplotlib.pyplot as plt

# CORRECT PATH (from eda/)
sensor_path = "../data/sensors/train_FD001.txt"

df = pd.read_csv(
    sensor_path,
    sep=r"\s+",      # IMPORTANT for NASA data
    header=None
)

df = df.dropna(axis=1)

print("✅ Sensor data loaded")
print("Shape:", df.shape)
import pandas as pd
import matplotlib.pyplot as plt

# CORRECT PATH (from eda/)
sensor_path = "../data/sensors/train_FD001.txt"

df = pd.read_csv(
    sensor_path,
    sep=r"\s+",      # IMPORTANT for NASA data
    header=None
)

df = df.dropna(axis=1)

print("✅ Sensor data loaded")
print("Shape:", df.shape)

plt.figure(figsize=(12,4))
plt.plot(df.iloc[:, 5])
plt.title("Sensor 5 Trend")
plt.xlabel("Time")
plt.ylabel("Sensor Value")
plt.show()
# Out:
# ✅ Sensor data loaded
# Shape: (20631, 26)
# ✅ Sensor data loaded
# Shape: (20631, 26)
# ✅ Sensor data loaded
# Shape: (20631, 26)
