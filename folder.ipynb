# %%
import os

folders = [
    "data/sensors", "data/images", "data/logs",
    "eda", "models/sensor_models", "models/image_models",
    "models/log_models", "fusion", "evaluation", "utils"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
